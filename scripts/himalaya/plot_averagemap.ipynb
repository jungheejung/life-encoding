# %%
from nilearn.plotting import plot_surf
import matplotlib.pyplot as plt
from nilearn import datasets
from os.path import join

# %%
fsaverage = datasets.fetch_surf_fsaverage(mesh = 'fsaverage6')

# %%
gii_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/ha_common'

# %%
def plot_infl(key, cmap):
    figure, axes = plt.subplots(1,2,subplot_kw={'projection': '3d'},figsize = (12,8))
    plot_surf(fsaverage['infl_left'],join(gii_dir,f'{key}_align-ha_common_sub-mean_run-mean_hemi-lh.gii'), 
              title=f'{key} lh', 
              hemi='left', view = 'lateral',cmap = cmap, axes=axes[0], colorbar=True) #vmin=.05, vmax=.5,
    plot_surf(fsaverage['infl_right'],join(gii_dir,f'{key}_align-ha_common_sub-mean_run-mean_hemi-rh.gii'), 
              title=f'{key} rh', 
              hemi='right', view = 'lateral', cmap = cmap, axes=axes[1], colorbar=True) #vmin=.05, vmax=.5,

    plt.show()

# %% [markdown]
# # r

# %%
plot_infl('agents-r', 'inferno')

# %%
plot_infl('bg-r', 'inferno')

# %%
plot_infl('actions-r', 'inferno')

# %% [markdown]
# # r2

# %%
plot_infl('agents-r2', 'inferno')

# %%
plot_infl('bg-r2', 'inferno')

# %%
plot_infl('actions-r2', 'inferno')

# %% [markdown]
# # comb-r

# %%
plot_infl('comb-r', 'inferno')

# %% [markdown]
# # comb-r2

# %%
plot_infl('comb-r2', 'inferno')

# %% [markdown]
# # comb-pred

# %%
plot_infl('comb-pred', 'inferno')

# %% [markdown]
# # ridge-coef

# %%
plot_infl('ridge-coef', 'inferno')

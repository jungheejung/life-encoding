# %% [markdown]
# # Overview
# This notebook identifies significant r values
# * fisherZ correct
# * stack across participants and runs
# * run t-test and identify r values greater than 0
# * reconvert fisherZ back to correlation coefficients
# * stack coefficients across hemisphere for multiple comparisons
# * save results in corresponding hemisphere while preserving medial/non-medial wall vertices

# %% [markdown]
# ### modules

# %%
import numpy as np
import pandas as pd
import os
from os.path import join
import scipy.stats
from statsmodels.stats.multitest import multipletests
import nibabel as nib
from pathlib import Path
from surfplot import Plot
from neuromaps.datasets import fetch_fsaverage, fetch_fslr
import matplotlib.pyplot as plt
from matplotlib import colors

# %% [markdown]
# ### function: write_gifti

# %%
def write_gifti(data, output_fn, template_fn):
    gii = nib.load(template_fn)
    for i in np.arange(gii.numDA):
        gii.remove_gifti_data_array(0)
    gda = nib.gifti.GiftiDataArray(data)
    gii.add_gifti_data_array(gda)
    # nib.gifti.giftiio.write(gii, output_fn)
    # BUG: AttributeError: module 'nibabel.gifti' has no attribute 'giftiio'
    nib.save(gii, output_fn)

# %% [markdown]
# ### parameters

# %%
suma_dir = '/Users/h/suma-fsaverage6'
main_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding'
main_dir = '/Volumes/life-encoding'
singlemodel_feature = 'agents'
output_dir = os.path.join(main_dir, 'results', 'himalaya', f"single-{singlemodel_feature}", 'ha_common_pca-40')
stat_dir = join(output_dir, 'stats')
alignment = 'ha_common'
feature_list = [ 'agents-r'] 
pca_comp = 40
runs = [1, 2, 3, 4]
hemis = ['lh', 'rh']
fmri_durs = {1: 374, 2: 346, 3: 377, 4: 412}
n_samples = 1509
n_vertices = 40962
n_medial = {'lh': 3486, 'rh': 3491}
subjects = ['sub-rid000001', 'sub-rid000005', 'sub-rid000006',
            'sub-rid000009', 'sub-rid000012', 'sub-rid000014',
            'sub-rid000017', 'sub-rid000019', 'sub-rid000024',
            'sub-rid000027', 'sub-rid000031', 'sub-rid000032',
            'sub-rid000033', 'sub-rid000034', 'sub-rid000036',
            'sub-rid000037', 'sub-rid000038', 'sub-rid000041']

# %% [markdown]
# # compute one sample t-tests

# %%
for result in feature_list:
    hemi_t = []
    hemi_p = []
    hemi_mean = []
    print(f"starting {result} ________________")
    for hemisphere in hemis:
        medial_mask = np.load(os.path.join(main_dir, 'data', f'fsaverage6_medial_{hemisphere}.npy'))
        assert np.sum(medial_mask) == n_medial[hemisphere]
        cortical_vertices = ~medial_mask # boolean (true for non-medials, false for medials)
        cortical_coords = np.where(cortical_vertices)[0] # returns indices of non-medials
        avg_all = []
        # NOTE 1. Fisher z transform per run per participant (np.arctanh)
        for test_subject in subjects:
            stack_fisherz_run = []
            for test_run in runs:           
                run_data = np.load(f"{output_dir}/{result}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_{test_subject}_run-{test_run}_hemi-{hemisphere}.npy")
                fisherz_run = np.arctanh(run_data[0, cortical_vertices])
                stack_fisherz_run.append(fisherz_run)
        
            # NOTE: 2. average (z-transformed) correlations across runs: yields 18 maps (1 per subject)
            avg_run = np.mean(np.vstack(stack_fisherz_run), axis = 0)
            avg_all.append(avg_run)
        fisherz_all = np.vstack(avg_all) # 18 x nonmedial (per hemi)

        # NOTE: 3. Scipy ttest_1samp to get t-value and p-value
        t, p = scipy.stats.ttest_1samp(fisherz_all, popmean=0,axis=0, alternative='greater')
        hemi_t.append(t)
        hemi_p.append(p)
        hemi_mean.append(np.tanh(np.nanmean(fisherz_all, axis = 0)))

    # %% NOTE: 4-1. concatenate (np.hstack) the two hemispheres p-values (and exclude medial wall) prior to computing FDR (load in cortical_vertices.npy)
    left_vert = hemi_p[0].shape[0]
    t_all = np.hstack(hemi_t)
    p_all = np.hstack(hemi_p)

    reject, q_all, _, _ = multipletests(p_all, method = 'fdr_bh')
    q_both = [q_all[:left_vert], q_all[left_vert:]]
    print("* completed t-tests for both hemispheres")
    hemilabels = ['lh', 'rh']
    Path(join(output_dir, 'stats')).mkdir(parents = True, exist_ok = True)
    for h, hemisphere in enumerate(hemis):
        stats = np.zeros((n_vertices))
        hemi_mean[h][q_both[h] >= .05] = 0
        medial_mask = np.load(os.path.join(main_dir, 'data', f'fsaverage6_medial_{hemisphere}.npy'))
        assert np.sum(medial_mask) == n_medial[hemisphere]
        cortical_vertices = ~medial_mask # boolean (true for non-medials, false for medials)
        cortical_coords = np.where(cortical_vertices)[0] # returns indices of non-medials
        stats[cortical_coords] = hemi_mean[h]
        save_fname = f"{output_dir}/stats/{result}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-{hemisphere}_ttest.gii"
        write_gifti(stats.astype(np.float32),
        template_fn = os.path.join(suma_dir, f"{hemilabels[h]}.pial.gii"), 
        output_fn = save_fname)
    print("* saved output (thresholded average r) for both hemispheres")
# Out:
# starting agents-r ________________
# * completed t-tests for both hemispheres
# * saved output (thresholded average r) for both hemispheres
# starting moten-r ________________
# * completed t-tests for both hemispheres
# * saved output (thresholded average r) for both hemispheres

# %% [markdown]
# # plot results in fslr
#
# plot t-test results in surfplots, Freesurfer surface plots

# %%
def fsaverage_to_fslr_and_plot(Lfname, Rfname, key, cmap='inferno'):
    from neuromaps.datasets import fetch_fslr
    from neuromaps.transforms import fsaverage_to_fslr
    giiL = nib.load(Lfname)
    giiR = nib.load(Rfname)
    L_fslr = fsaverage_to_fslr(giiL, target_density='32k', hemi='L', method='linear')
    R_fslr = fsaverage_to_fslr(giiR, target_density='32k', hemi='R', method='linear')
    
    surfaces_fslr = fetch_fslr()
    lh_fslr, rh_fslr = surfaces_fslr['inflated']

    color_range = (0,.15)
    p = Plot(surf_lh=lh_fslr, 
             surf_rh=rh_fslr, 
             size=(1000, 200), 
             zoom=1.2, layout='row', 
             views=['lateral', 'medial', 'ventral', 'posterior'], 
             mirror_views=True, brightness=.7)
    p.add_layer({'left': L_fslr[0], 
                'right': R_fslr[0]}, 
                cmap=cmap, cbar=True,
                color_range=color_range,
                cbar_label=key
                ) # YlOrRd_r
    cbar_kws = dict(outer_labels_only=True, pad=.02, n_ticks=2, decimals=3)
    fig = p.build(cbar_kws=cbar_kws)
    fig.show()

# %%
alignment = 'ha_common'
# ['bg', 'agents', 'actions', 'moten']
for feature in feature_list:
    Lfname = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-lh_ttest.gii"
    Rfname = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-rh_ttest.gii"
    fsaverage_to_fslr_and_plot(Lfname, Rfname, feature, cmap='inferno')
# Out:
# /var/folders/sq/9y9jm3711js9zfqyb64n8c840000gn/T/ipykernel_49610/2698941242.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # cluster thresholded
#
# We threshold the maps using work bench. The output is a (semi) boolean mask, thereby, we apply the mask back onto the t-test maps.
# Steps include
# * Workbench cluster threshold
# * multiply workbench mask with t-test maps
# * plot thresholded maps

# %% [markdown]
# ### workbench cluster threshold

# %%
from subprocess import call
# parameteres
hemis = ['lh', 'rh']
# feature_list = ['bg', 'agents', 'actions', 'moten']
clustersize = 20
hemi_dict = {'lh': 'L', 'rh': 'R'}
fsaverage_dir = '/Users/h/neuromaps-data/atlases/fsaverage'
stat_dir = join(output_dir, 'stats')
# stat_dir = '/Volumes/life-encoding/results/himalaya/moten/ha_common_pca-40/stats'

# thresholding via workbench
for hemi in hemis:
    for feature in feature_list:
        fsaverage_template = f"{fsaverage_dir}/tpl-fsaverage_den-41k_hemi-{hemi_dict[hemi]}_inflated.surf.gii"
        himalaya = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-{hemi}_ttest.gii"
        outputfname = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-{hemi}_ttest_cluster-{clustersize}.gii"
        return_code = call(f"wb_command -metric-find-clusters {fsaverage_template} {himalaya} 0 {clustersize} {outputfname}", shell=True)
print(f"Return: {return_code}")
# Out:
# WARNING: metric file '/Volumes/life-encoding/results/himalaya/single-agentsmoten/ha_common_pca-40/stats/agents-r_feature-agentsmoten_pca-40_align-ha_common_hemi-lh_ttest_cluster-20.gii' should be saved ending in .func.gii or .shape.gii, see wb_command -gifti-help
#
#
# WARNING: metric file '/Volumes/life-encoding/results/himalaya/single-agentsmoten/ha_common_pca-40/stats/moten-r_feature-agentsmoten_pca-40_align-ha_common_hemi-lh_ttest_cluster-20.gii' should be saved ending in .func.gii or .shape.gii, see wb_command -gifti-help
#
#
# WARNING: metric file '/Volumes/life-encoding/results/himalaya/single-agentsmoten/ha_common_pca-40/stats/agents-r_feature-agentsmoten_pca-40_align-ha_common_hemi-rh_ttest_cluster-20.gii' should be saved ending in .func.gii or .shape.gii, see wb_command -gifti-help
#
#
# WARNING: metric file '/Volumes/life-encoding/results/himalaya/single-agentsmoten/ha_common_pca-40/stats/moten-r_feature-agentsmoten_pca-40_align-ha_common_hemi-rh_ttest_cluster-20.gii' should be saved ending in .func.gii or .shape.gii, see wb_command -gifti-help
# Return: 0

# %% [markdown]
# ## check cluster maps
# The images will look like masks

# %%
for feature in feature_list:
    clusterthresL = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-lh_ttest_cluster-{clustersize}.gii"
    clusterthresR = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-rh_ttest_cluster-{clustersize}.gii"
    fsaverage_to_fslr_and_plot(clusterthresL, clusterthresR, f'{feature}', cmap = 'Reds')
# Out:
# /var/folders/sq/9y9jm3711js9zfqyb64n8c840000gn/T/ipykernel_49610/2698941242.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## multiply workbench cluster threshold maps to t-test maps

# %%
def write_gifti_v2(data, output_fn, template_fn):
    gii = nib.load(template_fn)
    for i in np.arange(gii.numDA):
        gii.remove_gifti_data_array(0)
    gda = nib.gifti.GiftiDataArray(data)
    gii.add_gifti_data_array(gda)
    # nib.gifti.write(gii, output_fn)
    gii.to_filename(output_fn)

hemis = ['lh', 'rh']
hemi_dict = {'lh': 'L', 'rh': 'R'}
clustersize = 20
fsaverage_dir = '/Users/h/neuromaps-data/atlases/fsaverage'

# thresholding via workbench
for hemi in hemis:
    for feature in feature_list:
        clustermask_fname = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-{hemi}_ttest_cluster-{clustersize}.gii"
        clustL = nib.load(clustermask_fname).agg_data() > 0
        himalaya_fname = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-40_align-ha_common_hemi-{hemi}_ttest.gii"
        himalaya = nib.load(himalaya_fname).agg_data()
        maskeddata = clustL * himalaya
        write_gifti_v2(maskeddata.astype(np.float32), 
            output_fn=f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-{hemi}_ttest_thres-cluster{clustersize}.gii",
            template_fn=f"{fsaverage_dir}/tpl-fsaverage_den-41k_hemi-{hemi_dict[hemi]}_pial.surf.gii")

# %% [markdown]
# ## plot thresholded maps in fslr

# %%
for feature in feature_list:
    thresL = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-lh_ttest_thres-cluster{clustersize}.gii"
    thresR = f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-rh_ttest_thres-cluster{clustersize}.gii"
    fsaverage_to_fslr_and_plot(thresL, thresR, f'{feature}', cmap = 'inferno')
# Out:
# /var/folders/sq/9y9jm3711js9zfqyb64n8c840000gn/T/ipykernel_49610/2698941242.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # plot fsaverage

# %%
for feature in feature_list:
    agentsL = nib.load(f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-lh_ttest.gii")
    agentsR = nib.load(f"{stat_dir}/{feature}_feature-{singlemodel_feature}_pca-{pca_comp}_align-{alignment}_hemi-rh_ttest.gii")
    print(np.max(agentsL.agg_data()))
    color_range = (0,.15)
    surfaces = fetch_fsaverage()
    lh, rh = surfaces['inflated']
    p = Plot(surf_lh=lh, surf_rh=rh, size=(1000, 200), zoom=1.2, layout='row', views=['lateral', 'medial', 'ventral'], 
            mirror_views=True, brightness=.7)
    p.add_layer({'left': agentsL, 
                'right': agentsR}, 
                cmap='inferno', cbar=True,
                color_range=color_range,
                cbar_label=feature
                ) # YlOrRd_r
    cbar_kws = dict(outer_labels_only=True, pad=.02, n_ticks=2, decimals=3)
    
    fig = p.build(cbar_kws=cbar_kws)
    fig.show()
# Out:
# 0.09708752
# /var/folders/sq/9y9jm3711js9zfqyb64n8c840000gn/T/ipykernel_49610/2245764366.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0.23155147

# %%
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
fname = 'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-AIP_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = '/Volumes/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])

# %%
stack_data
# Out:
# {'bg': [array([[-1.01764068e-01,  2.41637081e-02, -2.25147773e-02,
#           -5.03238998e-02, -7.77980015e-02, -6.90116361e-02,
#           -1.49045765e-01,  2.87570860e-02,  1.18869580e-01,
#           -6.19311593e-02, -6.98565412e-03, -4.77812812e-02,
#           -1.99048519e-02, -9.41916276e-03,  5.30763995e-03,
#           -2.92518735e-02, -4.17096242e-02, -3.85772251e-02,
#           -1.38215110e-01, -4.54934761e-02,  1.71400588e-02,
#           -6.19161054e-02,  5.44522144e-02,  2.80741286e-02,
#           -8.17145184e-02, -2.87128352e-02,  5.61573729e-03,
#            4.78142640e-03,  1.23938955e-01,  5.13254851e-02,
#           -8.51876214e-02, -1.94022227e-02, -3.22541073e-02,
#           -1.38075575e-01, -6.41275570e-02, -3.79183441e-02,
#           -4.81758416e-02, -1.11613825e-01, -9.07213241e-02,
#           -3.39389369e-02, -1.23704456e-01,  2.03390252e-02,
#           -2.53710989e-02, -2.83704940e-02, -3.63386720e-02,
# ...

# %%
import pandas as pd

roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)
# df.melt(var_name='key', value_name='value')

# %%
df
# Out:
#      performance feature space
# 0      -0.101764            bg
# 1       0.024164            bg
# 2      -0.022515            bg
# 3      -0.050324            bg
# 4      -0.077798            bg
# ..           ...           ...
# 827    -0.086314         moten
# 828    -0.137574         moten
# 829     0.111764         moten
# 830     0.017796         moten
# 831     0.102990         moten
#
# [832 rows x 2 columns]

# %%
sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            )
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# # Reduced 100 iteration AIP

# %%
roiname = "AIP"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_iter100/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## MT original annotation

# %%
fname = 'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-MT_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = '/Volumes/life-encoding/results/himalaya/roitest_MT_one_iter100/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            )
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## FFC (model_dir from w2v_features)

# %%
roiname = 'FFC'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_iter100/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            )
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## FFC (new_annotations from Cara dir)

# %%
roiname = 'FFC'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_newannot/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"New annotation: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## AIP (new_annotations from Cara dir)

# %%
roiname = 'AIP'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_newannot/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"New annotation: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## MT (new_annotations from Cara dir)

# %%
roiname = 'MT'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_newannot/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"New annotation: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## new annotation + 4TR MT

# %%
roiname = 'MT'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_newannot_3tr/ha_common_pca-40' #roitest_MT_one_newannot_3tr
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"New annotation 3TR: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## data dir MT (after all the shifting in the code)
# * purpose: check if this result is identical to data results above
# * Conclusion: not really <br>
# * Sources of differences (potentially)
# * shift in model vs. fmri

# %%
roiname = 'MT'
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_data/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"data dir, but after code change in shifting: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

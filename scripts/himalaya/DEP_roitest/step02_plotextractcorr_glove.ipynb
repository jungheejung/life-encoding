# %%
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
fname = 'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-MT_one_hemi-lh.npy'

# stack_dir = '/dartfs/rc/lab/D/DBIC/DBIC/f0042x1/life-encoding/results/himalaya/roitest_AIP_one/ha_common_pca-40'
stack_dir = '/Volumes/life-encoding/results/himalaya/roitest_MT_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])

# %%
stack_data
# Out:
# {'bg': [array([[ 0.17203587,  0.03177538,  0.01997398, -0.00352398,  0.06972697,
#            0.09956097,  0.11280478,  0.07212269,  0.0408699 ,  0.13181873,
#           -0.11573044,  0.09957899,  0.1343167 , -0.04825345,  0.09423696,
#            0.07997543,  0.04765679,  0.09360398, -0.03588131,  0.06554674,
#            0.05404725,  0.0280827 ,  0.12780991,  0.06350058, -0.06402649,
#            0.04010415,  0.16426688,  0.17342378, -0.04966481,  0.11013635,
#            0.03532382, -0.06595531, -0.01876112, -0.04942797, -0.17024082,
#            0.00862911,  0.09343835,  0.11815945,  0.1349555 ,  0.06287401,
#            0.07857051,  0.10691186, -0.04639431,  0.09437906,  0.04729001,
#            0.02081212,  0.09347965, -0.02631021,  0.02961925, -0.03879249,
#            0.04889817,  0.07842261,  0.04075186,  0.11411066,  0.12640248,
#            0.05277182, -0.07323807,  0.02119077,  0.13902131,  0.16492623,
#           -0.00755707,  0.08853452,  0.09504198,  0.13242537,  0.11645184,
#            0.11077935,  0.08697992,  0.06823355,  0.03041592,  0.03661719,
#            0.05797033,  0.02010244,  0.11984752, -0.00588438, -0.00036675,
#            0.0452825 , -0.00623042, -0.00024538, -0.00681878,  0.02715507,
#            0.05249268,  0.0510589 ,  0.07089138,  0.14717314,  0.13206711,
#            0.15784124,  0.13201788,  0.11143332,  0.00368561,  0.16839567,
#            0.04293631, -0.02201501, -0.02387519,  0.11371354,  0.11480559,
#            0.12082771,  0.13982692,  0.17432921,  0.08303847,  0.08168837,
#            0.08919409,  0.10733567,  0.11600671,  0.08382064,  0.02438078,
#           -0.06888965,  0.10318706, -0.05037375,  0.06701643,  0.10679341,
#            0.09411632,  0.03667962,  0.0663196 ,  0.07042879,  0.03939713,
#            0.06182799,  0.05262844,  0.06411822, -0.09929059,  0.06555444,
#           -0.03641163,  0.07336986,  0.0473101 ,  0.09305973,  0.10998584,
#            0.1371507 ,  0.15438101,  0.20346586, -0.02707572,  0.10140275,
#            0.07330807,  0.09601915,  0.11090461,  0.10749389,  0.07759932,
#            0.08636206,  0.0709227 , -0.01070052,  0.05644907,  0.07119644,
#            0.07352481, -0.04488823, -0.09207331,  0.03964452, -0.18022084,
#            0.00655675,  0.04050755,  0.05246808,  0.07557075,  0.1247054 ,
#            0.09402221,  0.11709247,  0.08272018,  0.03552185,  0.06017354,
#            0.18421076,  0.17106527,  0.08779296,  0.02211392,  0.1762017 ,
#            0.12696184, -0.03241598,  0.13558707]])],
#  'actions': [array([[0.12827292, 0.12046307, 0.194553  , 0.12466852, 0.28752518,
#           0.11876643, 0.16662632, 0.1802413 , 0.10249125, 0.14155884,
#           0.04627751, 0.06905805, 0.11550092, 0.24729709, 0.14197178,
#           -0.02811782, -0.0275976 , -0.02926175,  0.02432799,  0.02256321,
#           -0.03129442, -0.00733482, -0.00692088,  0.06755409,  0.0776467 ,
#           -0.02139757, -0.15410361, -0.08326009, -0.07424137, -0.12390796,
#           -0.13731788,  0.03258086,  0.00644703, -0.08282476, -0.03873412,
#           -0.10389155, -0.04923367, -0.05397617, -0.1021381 , -0.01718858,
#           -0.10763657, -0.07431499, -0.04231392, -0.08062737, -0.05270233,
#           -0.04557555, -0.03390362, -0.04016594, -0.03549809, -0.03085479,
#           -0.0753101 , -0.02749839, -0.04291566]])]}

# %%
import pandas as pd

roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)
# df.melt(var_name='key', value_name='value')

# %%
df
# Out:
#      performance feature space
# 0       0.172036            bg
# 1       0.031775            bg
# 2       0.019974            bg
# 3      -0.003524            bg
# 4       0.069727            bg
# ..           ...           ...
# 647    -0.035498         moten
# 648    -0.030855         moten
# 649    -0.075310         moten
# 650    -0.027498         moten
# 651    -0.042916         moten
#
# [652 rows x 2 columns]

# %%
roiname = 'MT'
sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## AIP (glove annotation)

# %%
roiname = "AIP"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## MT original annotation

# %%
roiname = "MT"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## FFC (glove)

# %%
roiname = "FFC"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## PHG (glove)

# %%
roiname = "PHG"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## V1 (glove)

# %%
roiname = "V1"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()

# %% [markdown]
# ## VMV (glove)

# %%
roiname = "VMV"
fname = f'split-r_pca-40_align-ha_common_sub-rid000005_run-1_roi-{roiname}_one_hemi-lh.npy'
stack_dir = f'/Volumes/life-encoding/results/himalaya/roitest_{roiname}_one_glove/ha_common_pca-40'
stack_data = {'bg': [], 'actions': [], 'agents': [], 'moten': []}
split_data = np.load(f'{stack_dir}/{fname}', allow_pickle=True).item()
for feature in stack_data:
    stack_data[feature].append(split_data[feature])



roi_df = {'performance': [],'feature space': []}
for k in stack_data:
    for v in stack_data[k][0][0]:
        roi_df['performance'].append(v)
        roi_df['feature space'].append(k)    
df = pd.DataFrame(roi_df)

sns.barplot(x="feature space", 
              y="performance", 
              data=df,
              order=['bg', 'agents', 'actions', 'moten']
            ).set_title(f"datadir: {roiname}")
# plt.ylim(-0.025, 0.08)
sns.despine()
